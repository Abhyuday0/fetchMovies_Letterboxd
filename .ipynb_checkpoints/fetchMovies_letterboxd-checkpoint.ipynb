# %%
from bs4 import BeautifulSoup
# import time
import requests
import json
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.service import Service
import pandas as pd

# %%
#define variables

url = "https://letterboxd.com/films/popular/decade/2010s/page/"
page_count = 1
soup = 0
link = 0

# %%
#To parse the given page
def parse_page(url = url):
    options = Options()
    options.add_argument("--headless")
    service = Service(executable_path= r"C:\Users\abhyu\Downloads\geckodriver-v0.32.1-win64\geckodriver.exe")
    driver = webdriver.Firefox(options=options, service=service)

    driver.get(url)

    soup = BeautifulSoup(driver.page_source, "html.parser")
    driver.quit()

    # print(soup.prettify)
    
    return soup

# %%
# def more_film_data(link=link):
#     film_soup = parse_page(link)

#     actor_data = film_soup.find_all('a', {"class" : "text-slug tooltip"}, limit= 3)
#     actors = []
#     for actor in actor_data:
#         actors.append(actor.text)

#     director = film_soup.find('a', {"class" : "prettify"}).text

#     country = film_soup.find('div', {"class" : "text-sluglist"}).text
#     #collect data

#     rating = film_soup.find('meta', {"name" : "twitter:data2"})["content"]
#     rating = int(rating.replace(' out of 5',''))

#     language = film_soup.find('a', {"class" : "text-slug"}).text
    
#     more_film_list = [rating, director, country]
#     more_film_list.append(actor_data)
    
#     return more_film_list

# %%
#Create a dataframe of all films in a given page
def collect_data(soup = soup):
    # ratings = soup.find_all('li', {"class" : "listitem poster-container"}) 
    list_of_movies = soup.find_all('div', {"data-component-class" : "globals.comps.FilmPosterComponent"}) 

    df_page = pd.DataFrame()

    #One movie at a time
    for attributes in list_of_movies:
        # print(attributes.get('data-film-name')+', '+ attributes.get('data-film-release-year'))
        link = 'https://letterboxd.com/' + attributes.get('data-film-link')
        row = [attributes.text, attributes.get('data-film-name'), attributes.get('data-film-release-year'), link, attributes.get('data-average-rating')]

        more_film_list = more_film_data(link)
        # row.append(more_film_list)

        df_row = pd.DataFrame(row)
        df_page = pd.concat([df_page, df_row], axis=1)
    
    
    return df_page

# %%
# loop over the pages
def page_loop(url=url, page_count=page_count):
    df = pd.DataFrame()
    
    for count in range(1, page_count):
        url = url + str(count)
        soup = parse_page(url)
        df_page = collect_data(soup)
        df = pd.concat([df, df_page])
        print(count)
    return df.transpose()

# %%
def get_data(url=url, page_count=page_count):
    df = page_loop(url, page_count)
    # df.columns = ["Name and Year", "Name", "Year", "Link", "Rating"]
    return df

# %%
df = get_data(url, page_count+1)
df
# Out:
# <bound method Tag.prettify of <html class="no-mobile js is-windows cssanimations backdropfilter csstransforms supports csstransforms3d csstransitions flexbox flexboxlegacy objectfit object-fit svg no-touchevents has-no-touch" id="html" lang="en"><!--<![endif]--><head>
# <meta charset="utf-8"/>
# <meta content="width=1024" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="Browse our database of over half a million movies." name="description"/>
# <meta content="https://letterboxd.com/films/popular/decade/2010s/" property="og:url"/>
# <meta content="Browse Films" property="og:title"/>
# <meta content="Browse our database of over half a million movies" property="og:description"/>
# <meta content="https://s.ltrbxd.com/static/img/default-share.e38c5d62.png" property="og:image"/>
# <meta content="Letterboxd" name="application-name"/>
# <meta content="#445566" name="theme-color"/>
# <meta content="#445566" name="msapplication-TileColor"/>
# ...

# %%
# #TEST
# link = 'https://letterboxd.com/film/parasite-2019/'

# film_soup = parse_page(link)

# #collect data
# film_data = film_soup.find('script', {"type" : "application/ld+json"})
# film_data.extract()
